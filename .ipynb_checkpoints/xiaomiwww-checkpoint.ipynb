# %%
page='''<html>
	<head>
		<meta charset="UTF-8">
		<title></title>
		<link rel="stylesheet" type="text/css" href="css/cjwt.css"/>
		<script src="./js/iconfont.js"></script>
	</head>
	<body>
		<style type="text/css">
			*{margin:0;padding: 0;}
			.icon {
				   width: 1em; height: 1em;
				   vertical-align: -0.15em;
				   fill: currentColor;
				   overflow: hidden;
				  }
				
			h2:before 
			{
			    content:url(https://s01.mifile.cn/i/logo-footer.png?v2);
			}
			.cjwt{width: 298px;
height:350px;
float: left;
border: 1px solid #F5F5F5;
list-style: none;
/*text-align: center;*/
background-color: white;

}
.x{
	list-style: none;
	border-color: #0000FF;
	
}
.cjwt>.x{
	margin: 40px;
}
/*.t2{
	list-style: none;
	border-color: #0000FF;
	
}*/
.t2>li{
	float: left;
	width: 298px;
    height: 200px;
	position: relative;
	text-align: center;
	/*list-style: none;*/
	border-color: #0000FF;
	background-color: white;
	margin:1px; 
	text-decoration: none;
}
.t2>li>a{
	text-decoration: none;
}
.t2>li>a>img{
	margin-top:50px;
	width: 60px;
	height: 60px;
	alt:' ';
}
.t2>li>a>span{
	display: block;
}
.t3>li{
	float: left;
	width: 298px;
    height: 298px;
	position: relative;
	text-align: center;
	list-style: none;
	border-color: #0000FF;
	background-color: white;
	margin:1px; 
	
}
.t3>li>a{
	text-decoration: none;
}
.t3>li>a>img{
	margin-top:50px;
	width: 60px;
	height: 100px;
	alt:' ';
}
.t3>li>a>span{
	display: block;
}
#zl{
	float:left;
	/*margin-top: 10px auto;*/
	margin:auto 3px;
	border-right-style: 1px solid red;
	text-underline-style: none;
	font-size: 12px;
	line-height: 40px;
	text-decoration: none;
}
#yr{
	float:right;
	font-size: 12px;
	line-height: 40px;
	margin:auto 3px;
}
.fu{
list-style: none;
float: left;
list-style-type: ;
}
.fu>li{
	float: left;
	line-height: 100px;
	margin:auto 10px;
}

#s2{
	width: 40px;
	height: 40px;
	border: 1px solid #F5F5F5;
	display: inline-block;
	text-align: center;
	margin:30px 0 30px 0px;
	float: right;
}

#s1{
	width: 250px;
	height: 40px;
	border: 1px solid #F5F5F5;
	display: inline-block;
	text-align: right;
	margin:30px 0 30px 50px;
	float: right;
	line-height: 40px;
}
#s1>a{
	background-color: #F5F5F5;
	margin-right: 5px;
	font-size: 12px;
	text-decoration: none;
}
#ic{
	
	width: 230px;
display: inline-block;
border-left: 1px solid #e0e0e0;
margin-top: 30px;
margin-bottom: 30px;
}
.bc{
	width: 160px;
	height: 110px;
	
	display: inline-block;
	float: left;
	
}
.bc>dl>dt{
	font-size: 14px;
margin-bottom: 20px;
}
.bc>dl>dd{
	font-size: 12px;
}
.la{
	
background: #fff;
color: #ff6700;
width: 120px;
height: 28px;
font-size: 12px;
line-height: 28px;
display: inline-block;
border: 1px solid #b0b0b0;
border-color: #ff6700;
}
.ll{
	width: 655px;
margin: 0px 5px;
background-color: ;

line-height: 18px;
display: inline-block;
font-size: 12px;
float: left;
}
.lll>img{
	width: 80px;
	height: 28px;
	
}
.lll{
	float: right;
}

			
		</style>
	<div class="">
		<div class="" style="height: 40px;background-color: black;margin: 0 auto;">
			<div class="" style="width: 1200px;height: 40px;margin: 0 auto;
				text-align: center;">
			
			<a href="" class="" id="zl">小米商城</a>
			<a href="" class="" id="zl">MIUI</a>
			<a href="" class="" id="zl">IoT</a>
			<a href="" class="" id="zl">云服务</a>
			<a href="" class="" id="zl">水滴</a>
			<a href="" class="" id="zl">金融</a>
			<a href="" class="" id="zl">有品</a>
			<a href="" class="" id="zl">Select Region</a>
			<a href="" class="" id="yr"> 
				<svg class="icon" aria-hidden="true">
  				<use xlink:href="#icon-gouwuche"></use>
				</svg>购物车</a>
			<a href="" class="" id="yr">消息通知</a>
			<a href="" class="" id="yr">注册</a>
			<a href="" class="" id="yr">登录</a>
		    </div>
		</div>
		<div class="" style="height: 100px;background-color: white;">
			<div class="" style="width: 1200px;height: 100px;margin: 0 auto;">
			<img src="https://s01.mifile.cn/i/logo-footer.png?v2" style=" text-align: center;
				width: 50px;
				height:50px;
				margin: 25px 50px 25px 0;
				float: left;"/>
			<ul id="x1" class="fu">
				<li>全部商品分类</li>
				<li>小米手机</li>
				<li>红米</li>
				<li>电视</li>
				<li>笔记本</li>
				<li>盒子</li>
				<li>新品</li>
				<li>路由器</li>
				<li>智能硬件</li>
				<li>服务</li>
				<li>社区</li>
			</ul>
			<div id="s2"></div>
			<div id="s1"><a href="https://item.mi.com/product/10000069.html">小米Note3</a><a href="https://item.mi.com/product/10000091.html">小米Note6开售</a></div>
					
		    </div>
		</div>
	</div>
	<div class="" style="background-color: #F5F5F5; margin-bottom: ;">
		<div class="class="" style="width: 1200px;margin: 0 auto;
				">
			<div class="" style="line-height: 40px;margin: 0 auto;
				font-size: 12px;">
			<a href="" style="text-decoration: none;">首页</a>
			/
			<a href="" style="text-decoration: none;">帮助中心</a>

		    </div>
			
			<div class="" style="">
			    <div class="" style="height: 250px;box-sizing: border-box;
                     width: 1200px;
                     position: relative;
                     transition-duration: 0.5s;
                 
                     float: left;">
			    	<img src="https://i1.mifile.cn/f/i/15/shoujishangmenweixiu/yijiuhuanxinbanner1226x250.jpg" style="width: 1200px;
			    		height: 250px;"/>
			   
			    </div>
			    <div class="" style="height: 400px;">
			    	<h1 style="font-size: 30px;">自助服务</h1>
			    	<div class="">
			    		<ul class="x t2">
			    			<li>
			    				<a href="https://service.order.mi.com/apply/front">			    				
			    				<img src="https://i1.mifile.cn/f/i/16/service/selfservice/service-icon-shouhoufuwu.png"/>	
					    		<span style="display: block;">申请售后服务</span>
				    			</a>		    				
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src="https://i1.mifile.cn/f/i/16/service/selfservice/service-icon-dingdan.png"/>
			    					<span id="">
			    						订单查询
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src="https://i1.mifile.cn/f/i/16/service/selfservice/service-icon-xmaccount.png"/>
			    					<span id="">
			    						小米账户
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src="https://i1.mifile.cn/a4/cms_14895585907373_GNERP.jpg"/>
			    					<span id="">
			    						售后县级受理点
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=https://i1.mifile.cn/f/i/16/service/selfservice/service-icon-wangdian.png""/>
			    					<span id="">
			    						授权服务网点
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src="https://i1.mifile.cn/f/i/16/service/selfservice/service-icon-anzhuang.png"/>
			    					<span id="">
			    						付费服务
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src="https://i1.mifile.cn/f/i/16/service/selfservice/service-icon-shouhouzc.png"/>
			    					<span id="">
			    						售后政策
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src="https://i1.mifile.cn/f/i/16/service/selfservice/service-icon-chaxun.png"/>
			    					<span id="">
			    						查询真伪
			    					</span>
			    				</a>
			    			</li>
			    			
			    		</ul>
			    		<div id="s3"></div>
			            <div id="s4"></div>
			    	</div>
			    </div>
			    <div class="" style="height: 700px;">
			    	<h1 style="font-size:30px;">产品支持</h1>
			    	<div class="">
			    		<ul class="x t3">
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						小米手机
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						红米手机
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						小米平板
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						智能硬件
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						小米电视
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						小米盒子
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						小米路由器
			    					</span>
			    				</a>
			    			</li>
			    			<li>
			    				<a href="">
			    					<img src=""/>
			    					<span id="">
			    						小米笔记本及周边产品
			    					</span>
			    				</a>
			    			</li>
			    			
			    		</ul>
			    	</div>
			    </div>
			    <div class="" style="height: 800px;">
			    	<div class="">
			    	
			    	<h1 style="font-size: 20px;">常见问题</h1>
			    	<div class="">
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li style="font-size: 20px;
			    					margin-bottom: 20px;">账户管理</li>
			    				<li>账号常见问题</li>
			    				<li>账户注册</li>
			    				<li>VIP认证</li>
			    				<li>忘记密码</li>
			    				<li>重置密保</li>
			    				<li>账号确认</li>
			    				<li>申诉解锁</li>
			    				
			    			</ul>
			    		</div>
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li style="font-size: 20px;
			    					margin-bottom: 20px;">购物指南</li>
			    				<li>购买时间</li>
			    				<li>包邮政策</li>
			    				<li>发货时效</li>
			    				<li>支付方式</li>
			    				<li>防诈骗提示</li>
			    				<li>下单及支付时效</li>
			    				<li>所有权与风险转移</li>
			    				<li>购物车常见问题和购物技巧</li>
			    			</ul>
			    		</div>
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    			</ul>
			    		</div>
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    			</ul>
			    		</div>
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    			</ul>
			    		</div>
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    			</ul>
			    		</div>
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    			</ul>
			    		</div>
			    		<div class="cjwt">
			    			<ul class="x">
			    				<li></li>
			    				<li></li>
			    				<li></li>
			    			</ul>
			    		</div>
			    	</div>
			    		
			    	</div>
			    </div>
		
		    </div>
			<h1 style="font-size:30px;">联系客服</h1>
		</div>
		<div class="" style="width:1200px;height: 730px; margin: 0 auto;">
			<div class="">
				
				<div class="" style="width:1200px;height:150px;margin: 5px auto;background-color: white;">
					<div class="" style="width: 100px;
						height: 100px;
						
						text-align: center;margin:25px 200px;
						float:left;
						background-image: url(https://c1.mifile.cn/f/i/17/service/contact-icon.png);
						background-position: top;">
					</div>
					<dl class="" style="float: left;
						margin-top: 50px;">
						<dt style="font-size: 18px;">7×24在线聊天</dt>
						<dd style="font-size: 14px;">专业客服在线对话，为您解决遇到的问题</dd>
					</dl>
					<a href="" style="
						background-color: red;
						text-align: center;
						margin-top: 50px;
						width: 150px;
						display: inline-block;
						height: 38px;
						line-height: 38px;
						text-decoration: none;
						margin-left: 150px;
						">
						立即咨询</a>
				</div>
				
				<div class="" style="width:1200px;height:300px;background-color: white;text-align: center;margin: 10px auto;">
					
					<span id="" style="text-align: center;
						display: inline-block;">
						
						<p style="text-align: center;
						display: inline-block;
						background-image: url(https://c1.mifile.cn/f/i/17/service/contact-icon.png);
						background-size: 100px 400px;
						background-repeat: no-repeat;
						width: 100px;
						height: 100px;
						margin-top:50px ;
						background-position-y: -100px;"></p>
						
						<p>小米商城热线</p>
						<p>手机、电视盒子、PC、智能硬件等</p>
						<p>400-100-5678</p>
						<p>8:00-18:00</p>
						
					</span>
					<span id="" style="text-align: center;
						display: inline-block;
						margin: auto 30px;">
						<p style="text-align: center;
						display: inline-block;
						background-image: url(https://c1.mifile.cn/f/i/17/service/contact-icon.png);
						background-size: 100px 400px;
						background-repeat: no-repeat;
						width: 100px;
						height: 100px;
						margin-top:50px ;
						background-position-y: -200px;"></p>
						<p>小米商城热线</p>
						<p>手机、电视盒子、PC、智能硬件等</p>
						<p>400-100-5678</p>
						<p>8:00-18:00</p>
					</span>
					<span id="" style="text-align: center;
						display: inline-block;">
						<p style="text-align: center;
						display: inline-block;
						background-image: url(https://c1.mifile.cn/f/i/17/service/contact-icon.png);
						background-size: 100px 400px;
						background-repeat: no-repeat;
						width: 100px;
						height: 100px;
						margin-top:50px ;
						background-position-y: -300px;"></p>
						<p>小米商城热线</p>
						<p>手机、电视盒子、PC、智能硬件等</p>
						<p>400-100-5678</p>
						<p>8:00-18:00</p>
					</span>
				</div>
				<div class="" style="width:1200px;height:160px;margin-bottom: 100px;background-color: white;
					background-image: url(https://c1.mifile.cn/f/i/17/service/contact-weixin.png?v3);">
				</div>
			</div>
		</div>		
	</div>
	
	
	
	
	<div class="">
		
		<div class="" style="width:1200px; margin: 5px auto;">
					<div class="" style="width:1200px;background-color: white;
						text-align: center;
						float:left;border-bottom: 1px solid #e0e0e0;margin-bottom: 40px;">
					<span id="ic" style="border-left: 0;">
						<svg class="icon" aria-hidden="true">
		  				<use xlink:href="#icon-buoumaotubiao46"></use>
						</svg>
						预约维修服务</span>
					<span id="ic">
						<svg class="icon" aria-hidden="true">
		  				<use xlink:href="#icon-7"></use>
						</svg>
						7天无理由退货</span>
					<span id="ic">
						<svg class="icon" aria-hidden="true">
		  				<use xlink:href="#icon-15"></use>
						</svg>
						15天免费换货</span>
					<span id="ic">
						<svg class="icon" aria-hidden="true">
		  				<use xlink:href="#icon-unie637"></use>
						</svg>
						满150元包邮</span>
					<span id="ic">
						<svg class="icon" aria-hidden="true">
		  				<use xlink:href="#icon-icon-"></use>
						</svg>
						520余家售后网点</span>
				    </div>
				    
				    <div class="" style="">
				    	<div class="bc">
				    		<dl>
				    			<dt>帮助中心</dt>
				    			<dd>账户管理 </dd>
				    			<dd>购物指南</dd>
				    			<dd>订单操作</dd>
				    		</dl>
				    	</div>
				    	<div class="bc">
				    		<dl>
				    			<dt>服务支持</dt>
				    			<dd>售后政策 </dd>
				    			<dd>自助服务</dd>
				    			<dd>相关下载</dd>
				    		</dl>
				    	</div>
				    	<div class="bc">
				    		<dl>
				    			<dt>线下门店</dt>
				    			<dd>小米之家 </dd>
				    			<dd>服务网点</dd>
				    			<dd>授权体验店</dd>
				    		</dl>
				    	</div>
				    	<div class="bc">
				    		<dl>
				    			<dt>关于小米</dt>
				    			<dd>了解小米 </dd>
				    			<dd>加入小米</dd>
				    			<dd>联系我们</dd>
				    		</dl>
				    	</div>
				    	<div class="bc">
				    		<dl>
				    			<dt>关注我们</dt>
				    			<dd>新浪微博 </dd>
				    			<dd>小米部落</dd>
				    			<dd>官方微信</dd>
				    		</dl>
				    	</div>
				    	<div class="bc" style="border-right: 1px solid #e0e0e0;">
				    		<dl>
				    			<dt>特色服务</dt>
				    			<dd>F码通道 </dd>
				    			<dd>购礼物码</dd>
				    			<dd>防伪查询</dd>
				    		</dl>
				    	</div>
				    	
				    	
				    	<div class="" style="text-align: center;">
				    		<dl>
				    			<dt>400-100-5678</dt>
				    			<dd>周一至周日 8:00-18:00 </dd>
				    			<dd>（仅收市话费）</dd>
				    			<dd class="la">
				    				<svg class="icon" aria-hidden="true">
					  				<use xlink:href="#icon-xinxi"></use>
									</svg>
				    				联系客服</dd>
				    		</dl>
				    	</div>
					
					
					
				    </div>
		</div>
		
	</div>
	
	<div class="" style="background-color: #F5F5F5;">
		
		<div class="" style="width:1200px;height: 200px;padding-top: 20px;margin: 30px auto;">
					<div class="" style="width:1200px;margin: 30px auto;background-color: white;">
						 <h2 style="display: inline;
							float: left;
						 	"></h2>
						 <div class="ll">
						 	<p>
						 		
						 		<a href="" class=""><span class="">小米商城</span></a>
						 		<a href="" class=""><span class="">MIUI</span></a>
						 		<a href="" class=""><span class="">米家</span></a>
						 		<a href="" class=""><span class="">米聊</span></a>
						 		<a href="" class=""><span class="">多看</span></a>
						 		<a href="" class=""><span class="">游戏</span></a>
						 		<a href="" class=""><span class="">音乐</span></a>
						 		<a href="" class=""><span class="">路由器</span></a>
						 		<a href="" class=""><span class="">米粉卡</span></a>
						 		<a href="" class=""><span class="">小米天猫店</span></a>
						 		<a href="" class=""><span class="">隐私政策</span></a>
						 		<a href="" class=""><span class="">问题反馈</span></a>
						 		<a href="" class=""><span class="">Select Region</span></a>
						 	</p>
						 	<p>©
						 		<a href="" class=""><span class="">mi.com</span></a>
						 		<a href="" class=""><span class="">京ICP证110507号 </span></a>
						 		<a href="" class=""><span class=""> 京ICP备10046444号</span></a>
						 		<a href="" class=""><span class="">京公网安备11010802020134号 </span></a>
						 		<a href="" class=""><span class=""> 京网文[2014]0059-0009号</span></a>
						 	</p>
						 	<p>
						 		违法和不良信息举报电话：185-0130-1238，本网站所列数据，除特殊说明，所有数据均出自我司实验室测试
						 	</p>
						 </div>
						 <div class="">
						 	<a href="" class="lll"><img src="https://i1.mifile.cn/f/i/17/site/truste.png"/></a>
						 	<a href="" class="lll"><img src="https://s01.mifile.cn/i/v-logo-2.png"/></a>
						 	<a href="" class="lll"><img src="https://s01.mifile.cn/i/v-logo-1.png"/></a>
						 	<a href="" class="lll"><img src="https://s01.mifile.cn/i/v-logo-3.png"/></a>
						 	<a href="" class="lll"><img src="https://i8.mifile.cn/b2c-mimall-media/ba10428a4f9495ac310fd0b5e0cf8370.png"/></a>
						 </div>						
					</div>
					<div class="" style="text-align: center;
						text-align: center;
						margin-top: 100px;
						font-size: 10px;
						color: darkgray;
						font-weight: 600;">
						<h1>探索黑科技，小米为发烧而生</h1>
					</div>
		</div>
	</div>	
		
	</body>
</html>

'''

# %%
from flask import Flask
app = Flask(__name__)

@app.route('/')
def index():
    return page

app.run()
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [02/May/2018 09:45:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [02/May/2018 09:45:08] "GET /css/cjwt.css HTTP/1.1" 404 -
# 127.0.0.1 - - [02/May/2018 09:45:08] "GET /js/iconfont.js HTTP/1.1" 404 -

# %%
from aip import AipFace
import base64

""" 你的 APPID AK SK """
APP_ID = '11262633'
API_KEY = 'vMCwrMzFb6AkgTqwac0IbXyg'
SECRET_KEY = '2vIr1XO9wviq0ma5KFKt0huC8fbhhwYo'

client = AipFace(APP_ID, API_KEY, SECRET_KEY)
jpg1 = base64.b64encode(open('./face/1.jpg', 'rb').read())
jpg1 = bytes.decode(jpg1)
jpg2 = base64.b64encode(open('./face/2.jpg', 'rb').read())
jpg2 = bytes.decode(jpg2)
# print(jpg1)
result = client.match([
    {
        'image': jpg1,
        'image_type': 'BASE64',
    },
    {
        'image':str(jpg2),
        'image_type': 'BASE64',
    }
])
result
# Out:
# {'cached': 0,
#  'error_code': 0,
#  'error_msg': 'SUCCESS',
#  'log_id': 3476881099,
#  'result': {'face_list': [{'face_token': '9b9b31cd7f51a186826671f67c30f496'},
#    {'face_token': '21f4ea68b2ee3ccb39643923218f9582'}],
#   'score': 98.53536224},
#  'timestamp': 1526637944}

# %%
from aip import AipFace
import base64

""" 你的 APPID AK SK """
APP_ID = '11262633'
API_KEY = 'vMCwrMzFb6AkgTqwac0IbXyg'
SECRET_KEY = '2vIr1XO9wviq0ma5KFKt0huC8fbhhwYo'
imageType = "BASE64"

client = AipFace(APP_ID, API_KEY, SECRET_KEY)
jpg1 = base64.b64encode(open('./3.jpg', 'rb').read())
jpg1 = bytes.decode(jpg1)
client.detect(jpg1, imageType)

# """ 如果有可选参数 """
# options = {}
# options["face_field"] = "age"
# options["max_face_num"] = 2
# options["face_type"] = "LIVE"

# """ 带参数调用人脸检测 """
# client.detect(image, imageType, options)
# Out:
# {'cached': 0,
#  'error_code': 0,
#  'error_msg': 'SUCCESS',
#  'log_id': 3439687130,
#  'result': {'face_list': [{'angle': {'pitch': 8.708130836,
#      'roll': -83.33369446,
#      'yaw': 16.52474403},
#     'face_probability': 1,
#     'face_token': '20fed7b388dabf752cbd17cbde699b85',
#     'location': {'height': 78,
#      'left': 367.6027527,
#      'rotation': -84,
#      'top': 481.6303406,
#      'width': 95}}],
#   'face_num': 1},
#  'timestamp': 1526981169}

# %%
from aip import AipFace
import base64

""" 你的 APPID AK SK """
APP_ID = '11262633'
API_KEY = 'vMCwrMzFb6AkgTqwac0IbXyg'
SECRET_KEY = '2vIr1XO9wviq0ma5KFKt0huC8fbhhwYo'
imageType = "BASE64"

client = AipFace(APP_ID, API_KEY, SECRET_KEY)
jpg1 = base64.b64encode(open('./3.jpg', 'rb').read())
jpg1 = bytes.decode(jpg1)
result = client.faceverify([
    {
        'image': jpg1,
        'image_type': 'BASE64',
        'face_field':'age,beauty,expression,faceshape,gender,glasses,landmark,race,quality,facetype,parsing'
    }
    
])
result
# Out:
# {'cached': 0,
#  'error_code': 0,
#  'error_msg': 'SUCCESS',
#      {'x': 371.7736206, 'y': 130.051651},
#      {'x': 386.9678345, 'y': 130.4963074},
#      {'x': 400.4686279, 'y': 140.9114075},
#      {'x': 387.6484985, 'y': 140.6643829},
#      {'x': 374.293396, 'y': 141.6056824},
#      {'x': 360.6357727, 'y': 144.9804993},
#      {'x': 326.6005859, 'y': 175.0589294},
#      {'x': 325.0444641, 'y': 187.5543213},
#      {'x': 323.6796875, 'y': 199.9356995},
#      {'x': 320.0447083, 'y': 219.7659912},
#      {'x': 332.5515747, 'y': 215.1329041},
#      {'x': 356.6548462, 'y': 210.428894},
#      {'x': 370.0678406, 'y': 209.4743042},
#      {'x': 359.3226929, 'y': 192.5883942},
#      {'x': 354.182312, 'y': 181.4794922},
#      {'x': 348.6647949, 'y': 170.5705261},
#      {'x': 341.5559692, 'y': 198.3456116},
#      {'x': 321.3585815, 'y': 256.4176636},
#      {'x': 331.2429504, 'y': 239.5203094},
#      {'x': 348.7086182, 'y': 232.0667419},
#      {'x': 367.7914429, 'y': 232.2771912},
#      {'x': 383.0604858, 'y': 243.7321777},
#      {'x': 366.8013306, 'y': 248.6445923},
#      {'x': 351.3687134, 'y': 250.984375},
#      {'x': 336.7552185, 'y': 255.1202393},
#      {'x': 334.84021, 'y': 247.2250366},
#      {'x': 350.7507324, 'y': 242.5880737},
#      {'x': 367.7086792, 'y': 240.7445068},
#      {'x': 366.2463989, 'y': 241.6174774},
#      {'x': 350.1307373, 'y': 242.534668},
#      {'x': 335.5341797, 'y': 248.1341553}],
#     'liveness': {'faceliveness': 0.1090804711, 'livemapscore': 0.3837512197},
#     'location': {'height': 167,
#      'left': 250.1019135,
#      'rotation': -12,
#      'top': 158.2533264,
#      'width': 169},
#     'parsing_info': '...',
#     'quality': {'blur': 1.049631422e-07,
#      'completeness': 1,
#      'illumination': 45,
#      'occlusion': {'chin_contour': 0.009090908803,
#       'left_cheek': 0.0005470459582,
#       'left_eye': 0.112499997,
#       'mouth': 0,
#       'nose': 0.08314606547,
#       'right_cheek': 0,
#       'right_eye': 0.3380900025}},
#     'race': {'probability': 0.9999860525, 'type': 'yellow'}}],
#   'face_liveness': 0.3837512197,
#   'thresholds': {'frr_1e-2': 0.9, 'frr_1e-3': 0.3, 'frr_1e-4': 0.05}},
#  'timestamp': 1527001634}

# %%
from aip import AipFace
import base64

""" 你的 APPID AK SK """
APP_ID = '11262633'
API_KEY = 'vMCwrMzFb6AkgTqwac0IbXyg'
SECRET_KEY = '2vIr1XO9wviq0ma5KFKt0huC8fbhhwYo'
imageType = "BASE64"

client = AipFace(APP_ID, API_KEY, SECRET_KEY)
jpg1 = base64.b64encode(open('./3.jpg', 'rb').read())
jpg1 = bytes.decode(jpg1)
result = client.faceverify([
    {
        'image': jpg1,
        'image_type': 'BASE64',
        'face_field':'age,beauty,expression,gender,glasses'
    }
    
])
result
# res = result
# Out:
# {'cached': 0,
#  'error_code': 0,
#  'error_msg': 'SUCCESS',
#  'log_id': 3441729312,
#  'result': {'face_list': [{'age': 41,
#     'angle': {'pitch': 7.69910717, 'roll': 4.485556602, 'yaw': 9.937272072},
#     'beauty': 30.93226624,
#     'expression': {'probability': 0.9889028668, 'type': 'smile'},
#     'face_probability': 1,
#     'face_token': '8ef3d7fcec85a63e01b6412104cd0f6c',
#     'gender': {'probability': 0.9996647835, 'type': 'female'},
#     'glasses': {'probability': 0.9999783039, 'type': 'none'},
#     'liveness': {'faceliveness': 0.6373285651, 'livemapscore': 0.8719344818},
#     'location': {'height': 155,
#      'left': 315.0611877,
#      'rotation': 4,
#      'top': 285.9367065,
#      'width': 154}}],
#   'face_liveness': 0.8719344818,
#   'thresholds': {'frr_1e-2': 0.9, 'frr_1e-3': 0.3, 'frr_1e-4': 0.05}},
#  'timestamp': 1527002665}

# %%
import numpy as np 
import cv2
import json

from aip import AipFace
import base64

""" 你的 APPID AK SK """
APP_ID = '11262633'
API_KEY = 'vMCwrMzFb6AkgTqwac0IbXyg'
SECRET_KEY = '2vIr1XO9wviq0ma5KFKt0huC8fbhhwYo'
imageType = "BASE64"

client = AipFace(APP_ID, API_KEY, SECRET_KEY)
jpg1 = base64.b64encode(open('./3.jpg', 'rb').read())
jpg1 = bytes.decode(jpg1)
res = client.faceverify([
    {
        'image': jpg1,
        'image_type': 'BASE64',
        'face_field':'age,beauty,expression,gender,glasses'
    }
    
])

# res =  json.loads(result)

jpg1 =  cv2.imread('./3.jpg')
for item in res['result']['face_list']:
    x1 = int(item['location']['left'])
    y1 = int(item['location']['top'])
    x2 = int(item['location']['left']+item['location']['width'])
    y2 = int(item['location']['top']+item['location']['height'])
    cv2.rectangle(jpg1, (x1,y1), (x2,y2), (0, 255, 0), 2)





cv2.imshow('capture',jpg1)
cv2.waitKey(0)
res
# Out:
# {'error_code': 0, 'error_msg': 'SUCCESS', 'log_id': 3431095088, 'timestamp': 1527002558, 'cached': 0, 'result': {'thresholds': {'frr_1e-4': 0.05, 'frr_1e-3': 0.3, 'frr_1e-2': 0.9}, 'face_liveness': 0.9315289587, 'face_list': [{'face_token': 'e3f882d30bb674c6bd0ffbf652eaa3b6', 'location': {'left': 305.5643005, 'top': 194.8833618, 'width': 171, 'height': 184, 'rotation': 4}, 'face_probability': 1, 'angle': {'yaw': 4.020702839, 'pitch': 1.829311013, 'roll': 4.574782372}, 'liveness': {'faceliveness': 0.7597981095, 'livemapscore': 0.9315289587}, 'age': 45, 'beauty': 32.07135773, 'expression': {'type': 'none', 'probability': 0.9970983267}, 'gender': {'type': 'male', 'probability': 0.9995474219}, 'glasses': {'type': 'none', 'probability': 0.9999967813}}]}}
# -1
